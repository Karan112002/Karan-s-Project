# %%
import pandas as pd

# %%
mat = pd.read_csv(r"C:\Users\karan\Desktop\Machine Learning\IPL DATASETS\matches.csv")
mat.head(5)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
mat.shape
# Out:
# (1095, 20)

# %%
mat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
mat.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
mat.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
deli = pd.read_csv(r"C:\Users\karan\Desktop\Machine Learning\IPL DATASETS\deliveries.csv")
deli.head(5)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
deli.shape
# Out:
# (260920, 17)

# %%
deli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
# ...

# %%
deli.describe()
# Out:
#            match_id         inning           over           ball  \
# count  2.609200e+05  260920.000000  260920.000000  260920.000000
# mean   9.070665e+05       1.483531       9.197677       3.624486
# std    3.679913e+05       0.502643       5.683484       1.814920
# min    3.359820e+05       1.000000       0.000000       1.000000
# 25%    5.483340e+05       1.000000       4.000000       2.000000
# 50%    9.809670e+05       1.000000       9.000000       4.000000
# 75%    1.254066e+06       2.000000      14.000000       5.000000
# max    1.426312e+06       6.000000      19.000000      11.000000
#
#         batsman_runs     extra_runs     total_runs      is_wicket
# count  260920.000000  260920.000000  260920.000000  260920.000000
# mean        1.265001       0.067806       1.332807       0.049632
# std         1.639298       0.343265       1.626416       0.217184
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
deli.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# is_wicket                0
# player_dismissed    247970
# dismissal_kind      247970
# fielder             251566
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
ipl_df = deli.merge(mat,how='left',left_on='match_id',right_on='id')
ipl_df.head(5)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  ...  toss_decision  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0  ...          field
# 1     2  BB McCullum  P Kumar   SC Ganguly             0  ...          field
# 2     3  BB McCullum  P Kumar   SC Ganguly             0  ...          field
# 3     4  BB McCullum  P Kumar   SC Ganguly             0  ...          field
# 4     5  BB McCullum  P Kumar   SC Ganguly             0  ...          field
#
# ...

# %%
ipl_df.replace(['Royal Challengers Bangalore','Kings XI Punjab','Delhi Daredevils','Rising Pune Supergiants'],
                  ['Royal Challengers Bengaluru','Punjab Kings','Delhi Capitals','Rising Pune Supergiant'],inplace=True)
ipl_df.head(5)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
#
#    ball       batter   bowler  non_striker  batsman_runs  ...  toss_decision  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0  ...          field
# 1     2  BB McCullum  P Kumar   SC Ganguly             0  ...          field
# 2     3  BB McCullum  P Kumar   SC Ganguly             0  ...          field
# 3     4  BB McCullum  P Kumar   SC Ganguly             0  ...          field
# 4     5  BB McCullum  P Kumar   SC Ganguly             0  ...          field
#
# ...

# %%
# All teams
team = pd.concat([ipl_df['team1'],ipl_df['team2']]).unique()
team
# Out:
# array(['Royal Challengers Bengaluru', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Deccan Chargers', 'Chennai Super Kings', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Sunrisers Hyderabad', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Lucknow Super Giants', 'Gujarat Titans'],
#       dtype=object)

# %%
# All Playes
players = pd.concat([ipl_df['batter'],ipl_df['bowler']]).unique()
players
# Out:
# array(['SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey',
#        'Mohammad Hafeez', 'R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis',
#        'CL White', 'MV Boucher', 'B Akhil', 'AA Noffke', 'P Kumar',
#        'Z Khan', 'SB Joshi', 'PA Patel', 'ML Hayden', 'MEK Hussey',
#        'MS Dhoni', 'SK Raina', 'JDP Oram', 'S Badrinath', 'K Goel',
#        'JR Hopes', 'KC Sangakkara', 'Yuvraj Singh', 'SM Katich',
#        'IK Pathan', 'T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif',
#        'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne',
#        'SK Trivedi', 'G Gambhir', 'V Sehwag', 'S Dhawan', 'L Ronchi',
#        'ST Jayasuriya', 'DJ Thornely', 'RV Uthappa', 'PR Shah',
#        'AM Nayar', 'SM Pollock', 'Harbhajan Singh', 'S Chanderpaul',
#        'LRPL Taylor', 'AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxman',
#        'A Symonds', 'RG Sharma', 'SB Styris', 'AS Yadav', 'SB Bangar',
#        'WPUJC Vaas', 'RP Singh', 'WP Saha', 'LR Shukla',
# ...

# %%
print('Total Matches Played:',mat.shape[0])
print(' \n Venues Played At:',mat['city'].unique())
# Out:
# Total Matches Played: 1095
#
#  Venues Played At: ['Bangalore' 'Chandigarh' 'Delhi' 'Mumbai' 'Kolkata' 'Jaipur' 'Hyderabad'
#  'Chennai' 'Cape Town' 'Port Elizabeth' 'Durban' 'Centurion' 'East London'
#  'Johannesburg' 'Kimberley' 'Bloemfontein' 'Ahmedabad' 'Cuttack' 'Nagpur'
#  'Dharamsala' 'Kochi' 'Indore' 'Visakhapatnam' 'Pune' 'Raipur' 'Ranchi'
#  'Abu Dhabi' nan 'Rajkot' 'Kanpur' 'Bengaluru' 'Dubai' 'Sharjah'
#  'Navi Mumbai' 'Lucknow' 'Guwahati' 'Mohali']

# %%
print('Total venues played at:',mat['city'].nunique())
print('\nTotal umpires1 ',mat['umpire1'].nunique())
print('\nTotal umpires2 ',mat['umpire2'].nunique())
# Out:
# Total venues played at: 36
#
# Total umpires1  62
#
# Total umpires2  62

# %%
mat["city"].value_counts().head(5)
# Out:
# city
# Mumbai       173
# Kolkata       93
# Delhi         90
# Chennai       85
# Hyderabad     77
# Name: count, dtype: int64

# %%
mat["toss_winner"].value_counts().head(5)
# Out:
# toss_winner
# Mumbai Indians                 143
# Kolkata Knight Riders          122
# Chennai Super Kings            122
# Rajasthan Royals               120
# Royal Challengers Bangalore    113
# Name: count, dtype: int64

# %%
mat["winner"].value_counts().head(5)
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Name: count, dtype: int64

# %%
mat["umpire1"].value_counts().head(10)
# Out:
# umpire1
# AK Chaudhary             115
# HDPK Dharmasena           79
# KN Ananthapadmanabhan     59
# CB Gaffaney               53
# Asad Rauf                 51
# Nitin Menon               50
# S Ravi                    48
# M Erasmus                 42
# Aleem Dar                 38
# BF Bowden                 36
# Name: count, dtype: int64

# %%
mat["umpire2"].value_counts().head(10)
# Out:
# umpire2
# S Ravi           83
# VK Sharma        61
# C Shamshuddin    60
# Nitin Menon      54
# SJA Taufel       54
# RJ Tucker        53
# VA Kulkarni      44
# CK Nandan        43
# YC Barde         36
# RB Tiffin        30
# Name: count, dtype: int64

# %%
mat["player_of_match"].value_counts().head(10)
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
df=mat.iloc[[mat['result_margin'].idxmax()]]
df
# Out:
#           id season   city        date match_type player_of_match  \
# 620  1082635   2017  Delhi  2017-05-06     League     LMP Simmons
#
#                 venue             team1           team2       toss_winner  \
# 620  Feroz Shah Kotla  Delhi Daredevils  Mumbai Indians  Delhi Daredevils
#
#     toss_decision          winner result  result_margin  target_runs  \
# 620         field  Mumbai Indians   runs          146.0        213.0
#
#      target_overs super_over method      umpire1    umpire2
# 620          20.0          N    NaN  Nitin Menon  CK Nandan

# %%
print('Toss Decisions in %\n',((mat['toss_decision']).value_counts())/1095*100)
# Out:
# Toss Decisions in %
#  toss_decision
# field    64.292237
# bat      35.707763
# Name: count, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(13,6))
sns.countplot(x='season',hue='toss_decision',data=mat)
plt.show()

# %%
df=mat[mat['toss_winner']==mat['winner']]
slices=[len(df),(1095-len(df))]
labels=['yes','no']
plt.pie(slices,labels=labels,startangle=90,shadow=True,explode=(0,0),autopct='%1.1f%%')
fig = plt.gcf()
fig.set_size_inches(5,5)
plt.show()

# %%
def toss_winner(x):
    if x.iloc[0]=='bat':
        return x.iloc[1]
    elif x.iloc[2]!=x.iloc[1]:
        return x.iloc[2]
    return x.iloc[3]

# %%
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)
df_copy=mat.copy()
df_copy['batting_team']=df_copy[['toss_decision','toss_winner','team1','team2']].apply(toss_winner,axis=1)
df_copy=df_copy.sort_values(by="target_runs",ascending=False).reset_index().drop_duplicates()
df_copy['target_runs']=df_copy['target_runs']-1
df_copy=df_copy[['batting_team','target_runs']].head(10)
df_copy
# Out:
#                   batting_team  target_runs
# 0          Sunrisers Hyderabad        287.0
# 1          Sunrisers Hyderabad        277.0
# 2        Kolkata Knight Riders        272.0
# 3          Sunrisers Hyderabad        266.0
# 4  Royal Challengers Bangalore        263.0
# 5        Kolkata Knight Riders        261.0
# 6               Delhi Capitals        257.0
# 7         Lucknow Super Giants        257.0
# 8  Royal Challengers Bangalore        248.0
# 9          Chennai Super Kings        246.0

# %%
df_copy=ipl_df[(ipl_df['batting_team']==ipl_df['winner']) & (ipl_df['inning']==2)].copy()
gb=df_copy.groupby(["batting_team","match_id"]).sum()
df_copy=gb['total_runs'].sort_values(ascending=False).reset_index()
df_copy=df_copy[['batting_team','total_runs']].head(10).rename({'batting_team':'Team','total_runs':'Runs'})
df_copy
# Out:
#           batting_team  total_runs
# 0         Punjab Kings         262
# 1     Rajasthan Royals         226
# 2     Rajasthan Royals         224
# 3       Mumbai Indians         219
# 4  Sunrisers Hyderabad         217
# 5     Rajasthan Royals         217
# 6       Mumbai Indians         216
# 7  Sunrisers Hyderabad         215
# 8       Delhi Capitals         214
# 9       Mumbai Indians         214

# %%
ax=deli[deli['batsman_runs']==6].batter.value_counts()[:10].plot.bar(width=0.8)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x(), p.get_height()+10))
plt.show()

# %%
ax=deli[deli['batsman_runs']==4].batter.value_counts()[:10].plot.bar(width=0.8)
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x(), p.get_height()+10))
plt.show()

# %%
# Step 1: Group by match and batter to calculate total runs per match for each batter
batter_match_runs = deli.groupby(['match_id', 'batter'])['batsman_runs'].sum().reset_index()

# Step 2: Add columns to check if score is a fifty or a hundred
batter_match_runs['fifty'] = batter_match_runs['batsman_runs'].between(50, 99)
batter_match_runs['hundred'] = batter_match_runs['batsman_runs'] >= 100

# Step 3: Aggregate number of 50s and 100s per batter
fifty_hundred_counts = batter_match_runs.groupby('batter')[['fifty', 'hundred']].sum().reset_index()

# Step 4: Sort the result by hundreds first, then fifties
fifty_hundred_counts = fifty_hundred_counts.sort_values(by=['hundred', 'fifty'], ascending=False)

# Step 5: Display the top 10
print(fifty_hundred_counts.head(10))
# Out:
#              batter  fifty  hundred
# 631         V Kohli     56        8
# 242      JC Buttler     19        7
# 124        CH Gayle     32        6
# 147       DA Warner     62        4
# 289        KL Rahul     37        4
# 564       SR Watson     21        4
# 592    Shubman Gill     20        4
# 30   AB de Villiers     41        3
# 572       SV Samson     25        3
# 512        S Dhawan     51        2

# %%
top_scores = deli.groupby(["match_id", "batter","batting_team"])["batsman_runs"].sum().reset_index()
top_scores.sort_values('batsman_runs', ascending=0).head(10)
# Out:
#        match_id          batter                 batting_team  batsman_runs
# 5302     598027        CH Gayle  Royal Challengers Bangalore           175
# 2        335982     BB McCullum        Kolkata Knight Riders           158
# 14108   1304112       Q de Kock         Lucknow Super Giants           140
# 7528     829795  AB de Villiers  Royal Challengers Bangalore           133
# 11583   1216510        KL Rahul              Kings XI Punjab           132
# 15383   1370352    Shubman Gill               Gujarat Titans           129
# 8359     980987  AB de Villiers  Royal Challengers Bangalore           129
# 4687     548372        CH Gayle  Royal Challengers Bangalore           128
# 10149   1136602         RR Pant             Delhi Daredevils           128
# 2237     419137         M Vijay          Chennai Super Kings           127

# %%
season_runs = ipl_df.groupby(['season', 'batter'])['batsman_runs'].sum().reset_index()

# Step 3: Sort by season and runs to get top scorers
top_scorers_per_season = season_runs.sort_values(['season', 'batsman_runs'], ascending=[True, False])

# Step 4: Get top 1 scorer for each season
top_scorers_by_season = top_scorers_per_season.groupby('season').head(1).reset_index(drop=True)

# Step 5: Display top scorers by season
print("Top run-scorers in each IPL season:")
print(top_scorers_by_season)

# Step 6: Find the all-time highest scorer in a single season
all_time_top = top_scorers_by_season.sort_values(by='batsman_runs', ascending=False).head(1)
print("\nAll-time highest scorer in a season:")
print(all_time_top)
# Out:
# Top run-scorers in each IPL season:
#      season         batter  batsman_runs
# 0   2007/08       SE Marsh           616
# 1      2009      ML Hayden           572
# 2   2009/10   SR Tendulkar           618
# 3      2011       CH Gayle           608
# 4      2012       CH Gayle           733
# 5      2013     MEK Hussey           733
# 6      2014     RV Uthappa           660
# 7      2015      DA Warner           562
# 8      2016        V Kohli           973
# 9      2017      DA Warner           641
# 10     2018  KS Williamson           735
# 11     2019      DA Warner           692
# 12  2020/21       KL Rahul           676
# 13     2021     RD Gaikwad           635
# 14     2022     JC Buttler           863
# 15     2023   Shubman Gill           890
# 16     2024        V Kohli           741
#
# All-time highest scorer in a season:
#   season   batter  batsman_runs
# 8   2016  V Kohli           973

# %%
import matplotlib.pyplot as plt

# Plot top scorer per season
plt.figure(figsize=(12, 6))
plt.bar(top_scorers_by_season['season'].astype(str), top_scorers_by_season['batsman_runs'], color='mediumseagreen')
plt.xticks(rotation=45)
plt.xlabel('Season')
plt.ylabel('Runs')
plt.title('Top Run-Scorer in Each IPL Season')
plt.tight_layout()
plt.show()

# %%
valid_dismissals = deli[
    (deli['is_wicket'] == 1) &
    (~deli['dismissal_kind'].isin(['run out', 'retired hurt', 'obstructing the field']))
]

# Count dismissals by bowler
wicket_counts = valid_dismissals.groupby('bowler')['player_dismissed'].count().reset_index()
wicket_counts.rename(columns={'player_dismissed': 'wickets'}, inplace=True)

# Sort by wickets and show top 10
top_wicket_takers = wicket_counts.sort_values(by='wickets', ascending=False).head(10)

print("Top 10 Wicket Takers in IPL:")
print(top_wicket_takers)
# Out:
# Top 10 Wicket Takers in IPL:
#          bowler  wickets
# 445   YS Chahal      205
# 297   PP Chawla      192
# 102    DJ Bravo      183
# 61      B Kumar      181
# 379   SP Narine      180
# 304    R Ashwin      180
# 7      A Mishra      174
# 372  SL Malinga      170
# 168   JJ Bumrah      168
# 319   RA Jadeja      160

# %%
# Filter for valid wicket types (exclude run outs and non-bowler dismissals)
valid_dismissals = deli[
    (deli['is_wicket'] == 1) &
    (~deli['dismissal_kind'].isin(['run out', 'retired hurt', 'obstructing the field']))
]

# Group by match and bowler to count wickets per match
match_wickets = valid_dismissals.groupby(['match_id', 'bowler'])['player_dismissed'].count().reset_index()
match_wickets.rename(columns={'player_dismissed': 'wickets'}, inplace=True)

# Sort to find highest wicket hauls in a single match
top_match_wickets = match_wickets.sort_values(by='wickets', ascending=False).head(10)

print("Top 10 Best Bowling Performances in a Match:")
print(top_match_wickets)
# Out:
# Top 10 Best Bowling Performances in a Match:
#       match_id         bowler  wickets
# 3697    980979        A Zampa        6
# 167     336005  Sohail Tanvir        6
# 4785   1178394      AS Joseph        6
# 383     392182       A Kumble        5
# 213     336013       L Balaji        5
# 6890   1370352      MM Sharma        5
# 7050   1422139    Yash Thakur        5
# 2379    598032    JP Faulkner        5
# 2597    598065    JP Faulkner        5
# 6136   1304086    Umran Malik        5

# %% [markdown]
# ## team vs team

# %%
def teamVteam(team1,team2):
    temp_df = mat[((mat['team1'] == team1) & (mat['team2'] == team2)) | 
        ((mat['team1'] == team2) & (mat['team2'] == team1))]
    total_matches = temp_df.shape[0]
    team1_wins = temp_df[temp_df['winner'] == team1].shape[0]
    team2_wins = temp_df[temp_df['winner'] == team2].shape[0]
    team1_win_per = (team1_wins/total_matches)*100
    team2_win_per = (team2_wins/total_matches)*100

    dic = {
        'team1' : team1,
        'team2' : team2,
        'total_matches':total_matches,
        'wins':{
            team1 : team1_wins,
            team2 : team2_wins
        },
        'winning_perc':{
            team1 : team1_win_per,
            team2 : team2_win_per
        }
        
    }
    return dic

# %%
teamVteam('Chennai Super Kings','Mumbai Indians')
# Out:
# {'team1': 'Chennai Super Kings',
#  'team2': 'Mumbai Indians',
#  'total_matches': 37,
#  'wins': {'Chennai Super Kings': 17, 'Mumbai Indians': 20},
#  'winning_perc': {'Chennai Super Kings': 45.94594594594595,
#   'Mumbai Indians': 54.054054054054056}}

# %% [markdown]
# ## Batsman Record

# %%
import numpy as np

def get_batsman_statistics(player_name, match_data):
    player_data = match_data[match_data['batter'] == player_name]

    # Filter data for first and second innings only
    innings_data = player_data[player_data['inning'].isin([1, 2])]

    # Batting stats
    total_runs = innings_data['batsman_runs'].sum()
    valid_balls_faced = innings_data[innings_data['extras_type'] != 'wides'].shape[0]
    strike_rate = round((total_runs / valid_balls_faced) * 100, 2) if valid_balls_faced > 0 else 0

    # Boundary count
    total_fours = (innings_data['batsman_runs'] == 4).sum()
    total_sixes = (innings_data['batsman_runs'] == 6).sum()

    # Dismissals and batting average
    dismissals = innings_data[innings_data['is_wicket'] == 1].shape[0]
    batting_average = round(total_runs / dismissals, 2) if dismissals > 0 else np.nan

    # Player of the Match awards
    player_of_match_awards = player_data[player_data['player_of_match'] == player_name].drop_duplicates('match_id').shape[0]

    # Highest score, fifties & centuries
    runs_per_match = player_data.groupby('match_id')['batsman_runs'].sum()
    highest_score = runs_per_match.max() if not runs_per_match.empty else 0
    total_fifties = runs_per_match[(runs_per_match >= 50) & (runs_per_match < 100)].count()
    total_centuries = runs_per_match[runs_per_match >= 100].count()

    # Not out innings
    total_innings = player_data['match_id'].nunique()
    not_outs = total_innings - dismissals

    # Return data as a dictionary for API use
    return {
        "player_name": player_name,
        "total_innings": total_innings,
        "total_runs": total_runs,
        "total_fours": total_fours,
        "total_sixes": total_sixes,
        "batting_average": batting_average,
        "strike_rate": strike_rate,
        "total_fifties": total_fifties,
        "total_centuries": total_centuries,
        "highest_score": highest_score,
        "not_outs": not_outs,
        "player_of_the_match_awards": player_of_match_awards
    }

# %%
get_batsman_statistics('V Kohli',ipl_df)
# Out:
# {'player_name': 'V Kohli',
#  'total_innings': 244,
#  'total_runs': 8004,
#  'total_fours': 706,
#  'total_sixes': 273,
#  'batting_average': 36.72,
#  'strike_rate': 131.97,
#  'total_fifties': 56,
#  'total_centuries': 8,
#  'highest_score': 113,
#  'not_outs': 26,
#  'player_of_the_match_awards': 18}

# %%
def PlayerVsTeam(player,team):
    team_player_df = ipl_df[ipl_df['bowling_team'] == team]
    return get_batsman_statistics(player,team_player_df)

PlayerVsTeam('V Kohli','Punjab Kings')
# Out:
# {'player_name': 'V Kohli',
#  'total_innings': 32,
#  'total_runs': 1030,
#  'total_fours': 108,
#  'total_sixes': 32,
#  'batting_average': 34.33,
#  'strike_rate': 133.77,
#  'total_fifties': 5,
#  'total_centuries': 1,
#  'highest_score': 113,
#  'not_outs': 2,
#  'player_of_the_match_awards': 3}

# %%
def batsman_vs_batsman(player1, player2, match_data):
    # Get individual stats for both batsmen
    stats_player1 = get_batsman_statistics(player1, match_data)
    stats_player2 = get_batsman_statistics(player2, match_data)

    # Return structured data
    return {
        "matchup_type": "batsman_vs_batsman",
        player1: stats_player1,
        player2: stats_player2
    }

batsman_vs_batsman('V Kohli','RG Sharma',ipl_df)
# Out:
# {'matchup_type': 'batsman_vs_batsman',
#  'V Kohli': {'player_name': 'V Kohli',
#   'total_innings': 244,
#   'total_runs': 8004,
#   'total_fours': 706,
#   'total_sixes': 273,
#   'batting_average': 36.72,
#   'strike_rate': 131.97,
#   'total_fifties': 56,
#   'total_centuries': 8,
#   'highest_score': 113,
#   'not_outs': 26,
#   'player_of_the_match_awards': 18},
#  'RG Sharma': {'player_name': 'RG Sharma',
#   'total_innings': 251,
#   'total_runs': 6628,
#   'total_fours': 599,
#   'total_sixes': 281,
#   'batting_average': 28.57,
#   'strike_rate': 131.14,
#   'total_fifties': 43,
#   'total_centuries': 2,
#   'highest_score': 109,
#   'not_outs': 19,
#   'player_of_the_match_awards': 19}}

# %%
# Get total runs for each player
batsman_totals = ipl_df.groupby('batter')['batsman_runs'].sum().sort_values(ascending=False)

# Select top 5 batsmen
top_10_batsmen = batsman_totals.head(10).index.tolist()

# Get stats for each player
batsman_stats = [get_batsman_statistics(player, ipl_df) for player in top_10_batsmen]

# Convert to DataFrame for easy plotting
batsman_df = pd.DataFrame(batsman_stats)
batsman_df.set_index("player_name", inplace=True)
batsman_df.reset_index()[['player_name','total_runs']]
# Out:
#       player_name  total_runs
# 0         V Kohli        8004
# 1        S Dhawan        6769
# 2       RG Sharma        6628
# 3       DA Warner        6565
# 4        SK Raina        5528
# 5        MS Dhoni        5243
# 6  AB de Villiers        5162
# 7        CH Gayle        4965
# 8      RV Uthappa        4952
# 9      KD Karthik        4842

# %%
# Group by batter to calculate total runs and valid balls faced (excluding wides)
batsman_stats_df = ipl_df.groupby('batter').agg(
    total_runs=('batsman_runs', 'sum'),
    balls_faced=('batsman_runs', lambda x: ipl_df.loc[x.index, 'extras_type'].ne('wides').sum())
)

# Calculate strike rate
batsman_stats_df['strike_rate'] = (batsman_stats_df['total_runs'] / batsman_stats_df['balls_faced']) * 100

# Filter for batsmen with at least 500 balls faced
qualified_batsmen = batsman_stats_df[batsman_stats_df['balls_faced'] >= 500]

# Sort by strike rate in descending order
qualified_batsmen = qualified_batsmen.sort_values(by='strike_rate', ascending=False)

# Get the player with the highest strike rate among qualified batsmen
top_strike_rate_player = qualified_batsmen.head(10).reset_index()

# Display result
print(top_strike_rate_player)
# Out:
#             batter  total_runs  balls_faced  strike_rate
# 0       AD Russell        2488         1423   174.841883
# 1        H Klaasen         993          590   168.305085
# 2        SP Narine        1534          925   165.837838
# 3   LS Livingstone         939          578   162.456747
# 4         N Pooran        1769         1092   161.996337
# 5       RM Patidar         799          503   158.846918
# 6       GJ Maxwell        2772         1769   156.698700
# 7         V Sehwag        2728         1755   155.441595
# 8  Abhishek Sharma        1377          887   155.242390
# 9       SO Hetmyer        1243          812   153.078818

# %%
# Filter dataset to include only 'caught' dismissals
catch_data = ipl_df[ipl_df['dismissal_kind'] == 'caught']

# Count the number of catches per player
fielder_catches = catch_data['fielder'].value_counts().reset_index()
fielder_catches.columns = ['player', 'total_catches']

# Get the top 10 fielders with most catches
top_10_fielders = fielder_catches.head(10)

# Display using styled dataframe
top_10_fielders
# Out:
#            player  total_catches
# 0        MS Dhoni            152
# 1      KD Karthik            145
# 2  AB de Villiers            120
# 3         V Kohli            114
# 4        SK Raina            106
# 5        S Dhawan            100
# 6       RG Sharma            100
# 7       RA Jadeja             97
# 8      KA Pollard             97
# 9         WP Saha             93

# %%
stats = ["total_runs", "batting_average", "strike_rate", "total_fours", "total_sixes", "highest_score"]
plt.figure(figsize=(6, 5))
sns.heatmap(batsman_df[stats], annot=True, cmap="Blues", linewidths=0.5, fmt=".1f")
plt.title("Top 5 Batsmen - Performance Heatmap", fontsize=16, fontweight="bold")
plt.xlabel("Metrics", fontsize=12)
plt.ylabel("Batsman", fontsize=12)
plt.show()

# %% [markdown]
# ## Bowler Stats

# %%
bowler_data = ipl_df.copy()
bowler_data.extras_type.value_counts()
# Out:
# extras_type
# wides      8380
# legbyes    4001
# noballs    1069
# byes        673
# penalty       2
# Name: count, dtype: int64

# %%
def bowlerRun(x):
    if x.iloc[0] in ['legbyes','penalty','byes']:
        return 0
    else:
        return x.iloc[1]

bowler_data["bowler_run"]=(bowler_data[['extras_type','total_runs']].apply(bowlerRun,axis=1))
bowler_data.head(5)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
#
#    ball       batter   bowler  non_striker  batsman_runs  ...  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0  ...
# 1     2  BB McCullum  P Kumar   SC Ganguly             0  ...
# 2     3  BB McCullum  P Kumar   SC Ganguly             0  ...
# 3     4  BB McCullum  P Kumar   SC Ganguly             0  ...
# 4     5  BB McCullum  P Kumar   SC Ganguly             0  ...
#
#                   winner  result result_margin  target_runs target_overs  \
# ...

# %%
def bowler_wicket(x):
    if x.iloc[0] in ["caught","bowled","lbw","caught and bowled","stumped","hit wicket"]:
        return x.iloc[1]
    else:
        return 0
bowler_data['isBowlerWicket']=bowler_data[['dismissal_kind','is_wicket']].apply(bowler_wicket,axis=1)
bowler_data.head(5)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
#
#    ball       batter   bowler  non_striker  batsman_runs  ...  result  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0  ...    runs
# 1     2  BB McCullum  P Kumar   SC Ganguly             0  ...    runs
# 2     3  BB McCullum  P Kumar   SC Ganguly             0  ...    runs
# 3     4  BB McCullum  P Kumar   SC Ganguly             0  ...    runs
# 4     5  BB McCullum  P Kumar   SC Ganguly             0  ...    runs
#
#    result_margin target_runs  target_overs super_over method    umpire1  \
# ...

# %%
def get_bowler_statistics(bowler, match_data):
    # Filter data for the bowler
    bowler_data = match_data[match_data['bowler'] == bowler].copy()

    if bowler_data.empty:
        return {}

    # Total innings played as a bowler
    total_innings = bowler_data['match_id'].nunique()

    # Total wickets (only bowler-induced dismissals)
    total_wickets = bowler_data["isBowlerWicket"].sum()

    # Total runs conceded (excluding leg byes, byes, and penalties)
    total_runs_conceded = bowler_data["bowler_run"].sum()

    # Total balls bowled (excluding wides & no-balls)
    valid_balls_bowled = bowler_data[~bowler_data["extras_type"].isin(["wides", "noballs"])].shape[0]

    # Economy rate (Runs per over)
    economy_rate = round((total_runs_conceded / (valid_balls_bowled / 6)), 2) if valid_balls_bowled > 0 else 0

    # Bowling average (Runs per wicket)
    bowling_average = round(total_runs_conceded / total_wickets, 2) if total_wickets > 0 else np.nan

    # Bowling strike rate (Balls per wicket)
    bowling_strike_rate = round(valid_balls_bowled / total_wickets, 2) if total_wickets > 0 else np.nan

    # Fours & Sixes Conceded
    total_fours_conceded = (bowler_data['batsman_runs'] == 4).sum()
    total_sixes_conceded = (bowler_data['batsman_runs'] == 6).sum()

    # 3-wicket, 4-wicket, and 5-wicket hauls
    wickets_per_match = bowler_data.groupby("match_id")["isBowlerWicket"].sum()
    three_wicket_hauls = (wickets_per_match >= 3).sum()
    four_wicket_hauls = (wickets_per_match >= 4).sum()
    five_wicket_hauls = (wickets_per_match >= 5).sum()

    # Best Bowling Figures (Wickets/Runs in a Match)
    best_wickets = wickets_per_match.max() if not wickets_per_match.empty else 0
    best_match_data = bowler_data.groupby("match_id")[["isBowlerWicket", "bowler_run"]].sum()
    best_bowling_match = best_match_data.loc[best_match_data["isBowlerWicket"].idxmax()] if not best_match_data.empty else None
    best_bowling_figure = f"{int(best_bowling_match['isBowlerWicket'])}/{int(best_bowling_match['bowler_run'])}" if best_bowling_match is not None else "0/0"

    # Man of the Match Awards (MOM)
    player_of_match_awards = bowler_data[bowler_data['player_of_match'] == bowler]['match_id'].nunique()

    return {
        "bowler": bowler,
        "innings": total_innings,
        "wickets": total_wickets,
        "economy": economy_rate,
        "average": bowling_average,
        "strikeRate": bowling_strike_rate,
        "fours": total_fours_conceded,
        "sixes": total_sixes_conceded,
        "best_figure": best_bowling_figure,
        "3w": three_wicket_hauls,
        "4w": four_wicket_hauls,
        "5w": five_wicket_hauls,
        "mom": player_of_match_awards
    }

# %%
get_bowler_statistics('YS Chahal',bowler_data)
# Out:
# {'bowler': 'YS Chahal',
#  'innings': 159,
#  'wickets': 205,
#  'economy': 7.84,
#  'average': 22.45,
#  'strikeRate': 17.18,
#  'fours': 275,
#  'sixes': 224,
#  'best_figure': '5/40',
#  '3w': 20,
#  '4w': 7,
#  '5w': 1,
#  'mom': 6}

# %%
def bowler_vs_team(bowler,team):
    temp_df = bowler_data[bowler_data['batting_team'] == team]
    return get_bowler_statistics(bowler,temp_df)

bowler_vs_team('RA Jadeja','Royal Challengers Bangalore')
# Out:
# {}

# %%
def bowler_vs_bowler(bowler1, bowler2):
    # Fetch statistics for both bowlers
    bowler1_stats = get_bowler_statistics(bowler1, bowler_data)
    bowler2_stats = get_bowler_statistics(bowler2, bowler_data)

    # Return a dictionary comparing both bowlers
    return {
        bowler1: bowler1_stats if bowler1_stats else {},
        bowler2: bowler2_stats if bowler2_stats else {}
    }

bowler_vs_bowler('JJ Bumrah','RA Jadeja')
# Out:
# {'JJ Bumrah': {'bowler': 'JJ Bumrah',
#   'innings': 133,
#   'wickets': 168,
#   'economy': 7.3,
#   'average': 22.28,
#   'strikeRate': 18.3,
#   'fours': 336,
#   'sixes': 112,
#   'best_figure': '5/29',
#   '3w': 24,
#   '4w': 5,
#   '5w': 3,
#   'mom': 10},
#  'RA Jadeja': {'bowler': 'RA Jadeja',
#   'innings': 211,
#   'wickets': 160,
#   'economy': 7.62,
#   'average': 30.4,
#   'strikeRate': 23.93,
#   'fours': 290,
#   'sixes': 207,
#   'best_figure': '5/16',
#   '3w': 17,
#   '4w': 4,
#   '5w': 1,
#   'mom': 16}}

# %% [markdown]
# ## Machine Learning Steps And Prediction In IPL DATASET

# %%
### Full Pipeline Code

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import joblib

# Data Cleansing
print("\nMissing values in Matches:")
print(mat.isnull().sum())

print("\nMissing values in Deliveries:")
print(deli.isnull().sum())

# Fill missing winner and city values
mat['winner'].fillna('No Result', inplace=True)
mat['city'].fillna('Dubai', inplace=True)

# Data Preprocessing
# Focus on relevant columns for prediction
features = mat[['team1', 'team2', 'toss_winner', 'toss_decision', 'venue']]
label = mat['winner']

# Encode categorical data
encoder = LabelEncoder()

for col in features.columns:
    features[col] = encoder.fit_transform(features[col])

label = encoder.fit_transform(label)

# Split data
X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.3, random_state=42)

# Optional: Feature scaling (mostly needed for SVM)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Model Training, Testing, Tuning

# 1. Random Forest
rf = RandomForestClassifier()
params_rf = {
    'n_estimators': [50, 100, 200],
    'max_depth': [5, 10, 20],
    'min_samples_split': [2, 5, 10]
}
gs_rf = GridSearchCV(rf, param_grid=params_rf, cv=5, verbose=1)
gs_rf.fit(X_train, y_train)

best_rf = gs_rf.best_estimator_
y_pred_rf = best_rf.predict(X_test)

print("\nRandom Forest Classification Report:")
print(classification_report(y_test, y_pred_rf))

# 2. Support Vector Machine (SVM)
svm = SVC()
params_svm = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf']
}
gs_svm = GridSearchCV(svm, param_grid=params_svm, cv=5, verbose=1)
gs_svm.fit(X_train_scaled, y_train)

best_svm = gs_svm.best_estimator_
y_pred_svm = best_svm.predict(X_test_scaled)

print("\nSVM Classification Report:")
print(classification_report(y_test, y_pred_svm))

# 3. Naive Bayes
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred_nb = nb.predict(X_test)

print("\nNaive Bayes Classification Report:")
print(classification_report(y_test, y_pred_nb))

# Compare Models
print("\nModel Comparison:")
print(f"Random Forest Accuracy: {accuracy_score(y_test, y_pred_rf)*100}")
print(f"SVM Accuracy: {accuracy_score(y_test, y_pred_svm)*100}")
print(f"Naive Bayes Accuracy: {accuracy_score(y_test, y_pred_nb)*100}")

# Select Best Model and Save
best_model = best_rf  # assuming RF performed the best

# Save the model
joblib.dump(best_model, f"{best_model}_final_best_model.pkl")

print("\nFinal model saved as 'final_best_model.pkl'")
# Out:
# Missing values in Matches:
# id                    0
# season                0
# city                  0
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                0
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64
#
# Missing values in Deliveries:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batter                   0
# bowler                   0
# non_striker              0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# extras_type         246795
# ...
